# %% [markdown]
# # Week 2: Python Basics (Part I) - Class Exercises
# Based on the concepts of Python Objects, Data Types, Data Structures, and Conditionals.

# %% [markdown]
# ## 1. Naming Objects & Assignment
# In Python, we use `snake_case` for variable names and the `=` operator to assign values.

# %% [markdown]
# #### **Your Turn!**
# 1. Create a variable named `current_city` and assign it the value "Singapore".
# 2. Create a variable named `visitor_count` and assign it the value 1500.
# 3. Use an f-string to print: "There are 1,500 visitors in Singapore today." (Hint: use `{visitor_count:,}` for the comma formatting).

# %%
current_city = "Singapore"
visitor_count = 1500

print(f"There are {visitor_count:,} visitors in {current_city} today.")
# Out:
# There are 1,500 visitors in Singapore today.

# %% [markdown]
# ## 2. Data Types & Coercion
# You can check types using `type()` and convert them using functions like `int()`, `float()`, or `str()`.

# %% [markdown]
# #### **Your Turn!**
# 1. Define a variable `price_string` with the value "19.99".
# 2. Convert `price_string` to a **float** and store it in a variable called `price_float`.
# 3. Check the type of `price_float` using `type()` and print it.

# %%
price_string = "19.99"
price_float = float(price_string)

print(type(price_float))
# Out:
# <class 'float'>

# %% [markdown]
# ## 3. Data Structures: Lists
# Lists are zero-indexed and mutable. Slicing syntax is `[start:stop]`, where the stop index is excluded.

# %% [markdown]
# #### **Your Turn!**
# Given the list of courses below:
# 1. Print the **first** course using its index.
# 2. Use slicing to print the **middle two** courses (`'ST5188'`, `'MA1521'`).
# 3. Append `'CS1010'` to the list and print the updated list.

# %%
courses = ['DSS5201', 'ST5188', 'MA1521', 'DSA3101']
# Type your code here:

# 1. Print the first course
print(courses[0])

# 2. Print the middle two courses using slicing
print(courses[1:3])

# 3. Append 'CS1010' and print the updated list
courses.append("CS1010")
print(courses)
# Out:
# DSS5201
# ['ST5188', 'MA1521']
# ['DSS5201', 'ST5188', 'MA1521', 'DSA3101', 'CS1010']

# %% [markdown]
# ## 4. Control Flow
# Use `if`, `elif`, and `else` to control the flow of your program based on conditions.

# %% [markdown]
# #### **Your Turn!**
# Define a variable `score = 74`.
# Write an `if-elif-else` statement that:
# - Prints "Distinction" if the score is 80 or above.
# - Prints "Pass" if the score is between 50 and 79.
# - Prints "Fail" otherwise.

# %%
score = 74
# Type your code here:


if score >= 80:
    print("Distinction")
elif score >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
